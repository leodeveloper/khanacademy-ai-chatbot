# %%
print('ok')
# Out:
# ok

# %%
# !pip show chromadb
# Out:
# Name: chromadb
# Version: 0.5.3
# Summary: Chroma.
# Home-page:
# Author:
# Author-email: Jeff Huber <jeff@trychroma.com>, Anton Troynikov <anton@trychroma.com>
# License:
# Location: /Users/muhammadsuleman/bbc-ai-chat-bot/envbbc/lib/python3.11/site-packages
# Requires: bcrypt, build, chroma-hnswlib, fastapi, grpcio, httpx, importlib-resources, kubernetes, mmh3, numpy, onnxruntime, opentelemetry-api, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, opentelemetry-sdk, orjson, overrides, posthog, pydantic, pypika, PyYAML, requests, tenacity, tokenizers, tqdm, typer, typing-extensions, uvicorn
# Required-by: langchain-chroma

# %%
# !pip install unstructured langchain-community langchain langchain-chroma langchain_groq sentence-transformers langchain-huggingface
# Out:
# ...
#   Using cached unstructured-0.14.6-py3-none-any.whl.metadata (28 kB)
# ...
#   Using cached langchain_community-0.2.5-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached langchain-0.2.5-py3-none-any.whl.metadata (7.0 kB)
# ...
#   Using cached langchain_chroma-0.1.1-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached langchain_groq-0.1.5-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached langchain_huggingface-0.0.3-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...

# %%
# !pip install langchain_chroma
